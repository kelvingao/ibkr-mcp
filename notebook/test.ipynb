# %%
from ib_async import *
util.startLoop

ib = IB()
ib.connect("127.0.0.1", 4001, clientId=111, account="U9860850")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 5
#       2 util.startLoop
#       4 ib = IB()
# ----> 5 ib.connect("127.0.0.1", 4001, clientId=111, account="U9860850")
#
# File ~/Documents/Projects/GitHub/ibkr-mcp/.venv/lib/python3.13/site-packages/ib_async/ib.py:369, in IB.connect(self, host, port, clientId, timeout, readonly, account, raiseSyncErrors, fetchFields)
#     329 def connect(
#     330     self,
#     331     host: str = "127.0.0.1",
#    (...)    338     fetchFields: StartupFetch = StartupFetchALL,
#     339 ):
#     340     """
#     341     Connect to a running TWS or IB gateway application.
#     342     After the connection is made the client is fully synchronized
#    (...)    367           to the ``fetchFields`` parameter as needed.
#     368     """
# --> 369     return self._run(
#     370         self.connectAsync(
# ...
